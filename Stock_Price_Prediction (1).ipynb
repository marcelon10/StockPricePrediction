# %% [markdown]
# # Stock Price Prediction using Machine Learning

# %% [markdown]
# As of general knowledge, stock market prices are unstable and unpredictable due to the many parameters that they are based on. Only a few of these parameters can be modeled in a mathematical way, making the prediction of stock prices using machine learning challenging and unreliable.

# %% [markdown]
# Despite this difficulties, it is possible to predict short-term fluctuations in the market for an average and uneventful day, using enough historical data and useful features to develop a machine learning model.

# %% [markdown]
# If we treat the stock data as a time-series data, we can use past stock prices to predict the prices in the next day or week. LSTM (Long Short-Term Memory) is often used to model this type of problem. We are going to weigh out the importance of older and recent data and determine which parameters affect the next day prices the most.

# %% [markdown]
# ### Implementation of the code

# %% [markdown]
# We will implement a simple LSTM network using TensorFlow Keras. We can work with actual stock prices dataset from major companies such as Microsoft, Apple or Facebook by downloading the data from [finances.yahoo.com](finances.yahoo.com).
#
# We are going to download the Netflix (NFLX) stock over 3 years. This dataset will be a .csv document containing data for Open, High, Low, Close, Adj Close and Volume for each date.

# %% [markdown]
# ### Downloading, analyzing and plotting the dataset

# %% [markdown]
# Having the dataset on hands, we will import the file as a DataFrame using Pandas, with each row representing data from a different date.

# %%
import pandas as pd
stock_data = pd.read_csv('NFLX (3).csv', index_col = 'Date')
stock_data.head()
stock_data.shape
# Out:
# (758, 6)

# %% [markdown]
# We can now plot the High and Low points of Netflix stocks over the last 3 years:

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt

plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]

plt.plot(x_dates, stock_data['High'], label = 'High')
plt.plot(x_dates, stock_data['Low'], label = 'Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# Using the same logic, we can plot the Open and Close values of the stock for each day:

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt

plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]

plt.plot(x_dates, stock_data['Open'], label = 'Open')
plt.plot(x_dates, stock_data['Close'], label = 'Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### Importing the Libraries

# %% [markdown]
# We will build our LSTM models using TensorFlow Keras and preprocessing our data using scikit-learn.

# %%
# %pip install -q tensorflow

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# We will now normalize the data within a fixed range to avoid features with larger numeric values to unjustly interfere and bias the model and help achieve rapid convergence.
#
# First of all, we will define the features and the target. Then, we will use a StandardScaler to rescale our values between -1 and 1.

# %%
target_y = stock_data['Close']
X_feat = stock_data.iloc[:,0:3]

sc = StandardScaler()
X_ft = sc.fit_transform(X_feat.values)
X_ft = pd.DataFrame(columns = X_feat.columns, data = X_ft, index = X_feat.index)

X_ft
# Out:
#                 Open      High       Low
# Date
# 2019-03-04 -0.849313 -0.878967 -0.905257
# 2019-03-05 -0.926939 -0.935638 -0.903261
# 2019-03-06 -0.906827 -0.901058 -0.870461
# 2019-03-07 -0.845178 -0.873282 -0.881869
# 2019-03-08 -0.980599 -0.993893 -0.958213
# ...              ...       ...       ...
# 2022-02-25 -0.596609 -0.608291 -0.643426
# 2022-02-28 -0.589843 -0.548079 -0.581153
# 2022-03-01 -0.549715 -0.573711 -0.566131
# 2022-03-02 -0.574807 -0.627585 -0.646943
# 2022-03-03 -0.602342 -0.656480 -0.747341
#
# [758 rows x 3 columns]

# %% [markdown]
# Now, we can see that the actual dataframe is normalized and possesses 757 data samples.

# %% [markdown]
# The next step would be to split our dataset into training and testing sets. The LSTM model requires a different approach to this splitting phase than the train_test_split method provided by scikit-learn.
#
# For this step, we will create a function called lstm_split, which takes the entire data and creates windows of size n_steps, starting from the beggining.

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data)-n_steps+1):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %% [markdown]
# ### Train and Test sets for Stock Price Prediction

# %% [markdown]
# We split our data into training and testing sets. Shuffling is not permitted in time-series datasets. In the beginning, we take two steps worth of past data to predict the current value. Thus, the model will look at yesterday’s and today’s values to predict today’s closing price.

# %%
X1, y1 = lstm_split(X_ft.values, n_steps=2)

train_split=0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = X_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[:split_idx], date_index[split_idx:]
X_test_date_shaped = X_test_date.tolist()
X_test_date_shaped.pop()

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (757, 2, 2) (606, 2, 2) (151, 2, 2) (151,)

# %% [markdown]
# ### Building the LSTM model

# %% [markdown]
# We will use the Sequential and LSTM modules provided by Tensorflow Keras to build a simple, single-unit LSTM model.

# %%
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 2, 32)             4480
#
#  dense_2 (Dense)             (None, 2, 1)              33
#
# =================================================================
# Total params: 4,513
# Trainable params: 4,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, we can fit a simple model to the training data:

# %%
history=lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 152/152 - 2s - loss: 0.4552 - 2s/epoch - 12ms/step
# Epoch 2/100
# 152/152 - 0s - loss: 0.1393 - 381ms/epoch - 3ms/step
# Epoch 3/100
# 152/152 - 0s - loss: 0.0758 - 362ms/epoch - 2ms/step
# Epoch 4/100
# 152/152 - 0s - loss: 0.0267 - 374ms/epoch - 2ms/step
# Epoch 5/100
# 152/152 - 0s - loss: 0.0135 - 446ms/epoch - 3ms/step
# Epoch 6/100
# 152/152 - 0s - loss: 0.0136 - 433ms/epoch - 3ms/step
# Epoch 7/100
# 152/152 - 0s - loss: 0.0136 - 384ms/epoch - 3ms/step
# Epoch 8/100
# 152/152 - 0s - loss: 0.0135 - 384ms/epoch - 3ms/step
# Epoch 9/100
# 152/152 - 0s - loss: 0.0135 - 376ms/epoch - 2ms/step
# Epoch 10/100
# 152/152 - 0s - loss: 0.0134 - 420ms/epoch - 3ms/step
# Epoch 11/100
# 152/152 - 0s - loss: 0.0134 - 500ms/epoch - 3ms/step
# Epoch 12/100
# 152/152 - 1s - loss: 0.0134 - 781ms/epoch - 5ms/step
# Epoch 13/100
# 152/152 - 1s - loss: 0.0134 - 729ms/epoch - 5ms/step
# Epoch 14/100
# 152/152 - 1s - loss: 0.0133 - 730ms/epoch - 5ms/step
# Epoch 15/100
# 152/152 - 1s - loss: 0.0133 - 742ms/epoch - 5ms/step
# Epoch 16/100
# 152/152 - 1s - loss: 0.0133 - 763ms/epoch - 5ms/step
# Epoch 17/100
# 152/152 - 1s - loss: 0.0133 - 640ms/epoch - 4ms/step
# Epoch 18/100
# 152/152 - 1s - loss: 0.0133 - 753ms/epoch - 5ms/step
# Epoch 19/100
# 152/152 - 1s - loss: 0.0133 - 664ms/epoch - 4ms/step
# Epoch 20/100
# 152/152 - 1s - loss: 0.0133 - 1s/epoch - 7ms/step
# Epoch 21/100
# 152/152 - 1s - loss: 0.0132 - 1s/epoch - 7ms/step
# Epoch 22/100
# 152/152 - 1s - loss: 0.0132 - 1s/epoch - 8ms/step
# Epoch 23/100
# 152/152 - 1s - loss: 0.0133 - 543ms/epoch - 4ms/step
# Epoch 24/100
# 152/152 - 1s - loss: 0.0132 - 643ms/epoch - 4ms/step
# Epoch 25/100
# 152/152 - 1s - loss: 0.0132 - 673ms/epoch - 4ms/step
# Epoch 26/100
# 152/152 - 1s - loss: 0.0133 - 599ms/epoch - 4ms/step
# Epoch 27/100
# 152/152 - 1s - loss: 0.0133 - 604ms/epoch - 4ms/step
# Epoch 28/100
# 152/152 - 1s - loss: 0.0133 - 628ms/epoch - 4ms/step
# Epoch 29/100
# 152/152 - 1s - loss: 0.0134 - 569ms/epoch - 4ms/step
# Epoch 30/100
# 152/152 - 1s - loss: 0.0135 - 509ms/epoch - 3ms/step
# Epoch 31/100
# 152/152 - 1s - loss: 0.0135 - 693ms/epoch - 5ms/step
# Epoch 32/100
# 152/152 - 1s - loss: 0.0136 - 725ms/epoch - 5ms/step
# Epoch 33/100
# 152/152 - 1s - loss: 0.0136 - 700ms/epoch - 5ms/step
# Epoch 34/100
# 152/152 - 1s - loss: 0.0137 - 643ms/epoch - 4ms/step
# Epoch 35/100
# 152/152 - 1s - loss: 0.0138 - 832ms/epoch - 5ms/step
# Epoch 36/100
# 152/152 - 1s - loss: 0.0139 - 637ms/epoch - 4ms/step
# Epoch 37/100
# 152/152 - 1s - loss: 0.0140 - 711ms/epoch - 5ms/step
# Epoch 38/100
# 152/152 - 1s - loss: 0.0141 - 813ms/epoch - 5ms/step
# Epoch 39/100
# 152/152 - 1s - loss: 0.0142 - 595ms/epoch - 4ms/step
# Epoch 40/100
# 152/152 - 1s - loss: 0.0142 - 566ms/epoch - 4ms/step
# Epoch 41/100
# 152/152 - 1s - loss: 0.0144 - 693ms/epoch - 5ms/step
# Epoch 42/100
# 152/152 - 1s - loss: 0.0141 - 738ms/epoch - 5ms/step
# Epoch 43/100
# 152/152 - 1s - loss: 0.0143 - 675ms/epoch - 4ms/step
# Epoch 44/100
# 152/152 - 1s - loss: 0.0144 - 647ms/epoch - 4ms/step
# Epoch 45/100
# 152/152 - 1s - loss: 0.0144 - 830ms/epoch - 5ms/step
# Epoch 46/100
# 152/152 - 0s - loss: 0.0144 - 373ms/epoch - 2ms/step
# Epoch 47/100
# 152/152 - 0s - loss: 0.0144 - 394ms/epoch - 3ms/step
# Epoch 48/100
# 152/152 - 0s - loss: 0.0143 - 378ms/epoch - 2ms/step
# Epoch 49/100
# 152/152 - 0s - loss: 0.0143 - 382ms/epoch - 3ms/step
# Epoch 50/100
# 152/152 - 0s - loss: 0.0143 - 386ms/epoch - 3ms/step
# Epoch 51/100
# 152/152 - 0s - loss: 0.0142 - 378ms/epoch - 2ms/step
# Epoch 52/100
# 152/152 - 0s - loss: 0.0142 - 397ms/epoch - 3ms/step
# Epoch 53/100
# 152/152 - 0s - loss: 0.0140 - 391ms/epoch - 3ms/step
# Epoch 54/100
# 152/152 - 0s - loss: 0.0140 - 394ms/epoch - 3ms/step
# Epoch 55/100
# 152/152 - 0s - loss: 0.0139 - 373ms/epoch - 2ms/step
# Epoch 56/100
# 152/152 - 0s - loss: 0.0138 - 389ms/epoch - 3ms/step
# Epoch 57/100
# 152/152 - 0s - loss: 0.0137 - 373ms/epoch - 2ms/step
# Epoch 58/100
# 152/152 - 0s - loss: 0.0137 - 379ms/epoch - 2ms/step
# Epoch 59/100
# 152/152 - 0s - loss: 0.0137 - 344ms/epoch - 2ms/step
# Epoch 60/100
# 152/152 - 0s - loss: 0.0137 - 394ms/epoch - 3ms/step
# Epoch 61/100
# 152/152 - 0s - loss: 0.0136 - 375ms/epoch - 2ms/step
# Epoch 62/100
# 152/152 - 0s - loss: 0.0136 - 375ms/epoch - 2ms/step
# Epoch 63/100
# 152/152 - 0s - loss: 0.0135 - 354ms/epoch - 2ms/step
# Epoch 64/100
# 152/152 - 0s - loss: 0.0135 - 364ms/epoch - 2ms/step
# Epoch 65/100
# 152/152 - 0s - loss: 0.0135 - 377ms/epoch - 2ms/step
# Epoch 66/100
# 152/152 - 0s - loss: 0.0135 - 408ms/epoch - 3ms/step
# Epoch 67/100
# 152/152 - 0s - loss: 0.0135 - 376ms/epoch - 2ms/step
# Epoch 68/100
# 152/152 - 0s - loss: 0.0134 - 372ms/epoch - 2ms/step
# Epoch 69/100
# 152/152 - 0s - loss: 0.0135 - 411ms/epoch - 3ms/step
# Epoch 70/100
# 152/152 - 0s - loss: 0.0134 - 416ms/epoch - 3ms/step
# Epoch 71/100
# 152/152 - 0s - loss: 0.0134 - 403ms/epoch - 3ms/step
# Epoch 72/100
# 152/152 - 0s - loss: 0.0134 - 383ms/epoch - 3ms/step
# Epoch 73/100
# 152/152 - 0s - loss: 0.0134 - 389ms/epoch - 3ms/step
# Epoch 74/100
# 152/152 - 0s - loss: 0.0134 - 372ms/epoch - 2ms/step
# Epoch 75/100
# 152/152 - 0s - loss: 0.0134 - 373ms/epoch - 2ms/step
# Epoch 76/100
# 152/152 - 0s - loss: 0.0134 - 380ms/epoch - 2ms/step
# Epoch 77/100
# 152/152 - 0s - loss: 0.0134 - 392ms/epoch - 3ms/step
# Epoch 78/100
# 152/152 - 0s - loss: 0.0133 - 385ms/epoch - 3ms/step
# Epoch 79/100
# 152/152 - 0s - loss: 0.0133 - 390ms/epoch - 3ms/step
# Epoch 80/100
# 152/152 - 0s - loss: 0.0133 - 360ms/epoch - 2ms/step
# Epoch 81/100
# 152/152 - 0s - loss: 0.0133 - 364ms/epoch - 2ms/step
# Epoch 82/100
# 152/152 - 0s - loss: 0.0133 - 373ms/epoch - 2ms/step
# Epoch 83/100
# 152/152 - 0s - loss: 0.0132 - 372ms/epoch - 2ms/step
# Epoch 84/100
# 152/152 - 0s - loss: 0.0132 - 363ms/epoch - 2ms/step
# Epoch 85/100
# 152/152 - 0s - loss: 0.0132 - 366ms/epoch - 2ms/step
# Epoch 86/100
# 152/152 - 0s - loss: 0.0132 - 369ms/epoch - 2ms/step
# Epoch 87/100
# 152/152 - 0s - loss: 0.0132 - 365ms/epoch - 2ms/step
# Epoch 88/100
# 152/152 - 0s - loss: 0.0132 - 360ms/epoch - 2ms/step
# Epoch 89/100
# 152/152 - 0s - loss: 0.0132 - 355ms/epoch - 2ms/step
# Epoch 90/100
# 152/152 - 0s - loss: 0.0131 - 359ms/epoch - 2ms/step
# Epoch 91/100
# 152/152 - 0s - loss: 0.0131 - 384ms/epoch - 3ms/step
# Epoch 92/100
# 152/152 - 0s - loss: 0.0131 - 391ms/epoch - 3ms/step
# Epoch 93/100
# 152/152 - 0s - loss: 0.0131 - 378ms/epoch - 2ms/step
# Epoch 94/100
# 152/152 - 0s - loss: 0.0131 - 368ms/epoch - 2ms/step
# Epoch 95/100
# 152/152 - 0s - loss: 0.0131 - 358ms/epoch - 2ms/step
# Epoch 96/100
# 152/152 - 0s - loss: 0.0131 - 375ms/epoch - 2ms/step
# Epoch 97/100
# 152/152 - 0s - loss: 0.0131 - 365ms/epoch - 2ms/step
# Epoch 98/100
# 152/152 - 0s - loss: 0.0131 - 354ms/epoch - 2ms/step
# Epoch 99/100
# 152/152 - 0s - loss: 0.0131 - 370ms/epoch - 2ms/step
# Epoch 100/100
# 152/152 - 0s - loss: 0.0130 - 386ms/epoch - 3ms/step

# %% [markdown]
# ### Performance Evaluation on Test Set

# %%
y_pred = lstm.predict(X_test)
y_pred = y_pred[:,0,0]
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
y_pred
# Out:
# array([ 0.67282087,  0.65031123,  0.61840105,  0.6426228 ,  0.606972  ,
#         0.6118052 ,  0.6590655 ,  0.6909671 ,  0.66280293,  0.65050733,
#         0.63379437,  0.58620924,  0.62529904,  0.6435229 ,  0.6332339 ,
#         0.6739019 ,  0.77242076,  0.86097145,  0.8796464 ,  0.8988503 ,
#         0.8848027 ,  0.8693384 ,  0.9324815 ,  0.9647633 ,  1.007021  ,
#         1.1024247 ,  1.1888777 ,  1.1702911 ,  1.2937498 ,  1.3381125 ,
#         1.3242108 ,  1.2899338 ,  1.2482015 ,  1.1486539 ,  1.111798  ,
#         1.1470966 ,  1.1721855 ,  1.1728637 ,  1.1017109 ,  1.1608096 ,
#         1.219617  ,  1.2014564 ,  1.185556  ,  1.2132744 ,  1.2553343 ,
#         1.3694307 ,  1.3373146 ,  1.4208431 ,  1.4558532 ,  1.5404856 ,
#         1.6307263 ,  1.5827702 ,  1.5602089 ,  1.5520681 ,  1.5255796 ,
#         1.5454041 ,  1.5809952 ,  1.551239  ,  1.5831574 ,  1.5190216 ,
#         1.604134  ,  1.7525953 ,  1.8517104 ,  1.9005066 ,  1.8563806 ,
#         1.8888677 ,  1.9608325 ,  2.0316198 ,  1.9933926 ,  1.9735347 ,
#         1.9987532 ,  1.8083352 ,  1.7052807 ,  1.7397821 ,  1.7359599 ,
#         1.7471024 ,  1.8673989 ,  1.9739136 ,  1.9736718 ,  2.0852187 ,
#         2.0515857 ,  2.0659182 ,  1.9240967 ,  1.7854716 ,  1.7632048 ,
#         1.9059035 ,  1.8150018 ,  1.8699971 ,  1.6953596 ,  1.4333872 ,
#         1.457746  ,  1.3539761 ,  1.4594041 ,  1.5174015 ,  1.4978408 ,
#         1.4006797 ,  1.3599478 ,  1.2635854 ,  1.2749826 ,  1.2591188 ,
#         1.1989397 ,  1.2161433 ,  1.2808704 ,  1.3329735 ,  1.3955598 ,
#         1.3820211 ,  1.3958246 ,  1.3601139 ,  1.3967341 ,  1.3576411 ,
#         1.3228606 ,  1.2610003 ,  1.1988918 ,  0.9395863 ,  0.8844421 ,
#         0.8088964 ,  0.8043743 ,  0.8316962 ,  0.7932019 ,  0.71408916,
#         0.6549543 ,  0.6418761 ,  0.6665045 , -0.4726578 , -0.65654224,
#        -0.6729835 , -0.70144063, -0.62466156, -0.6465685 , -0.36678845,
#        -0.04139721, -0.00220333, -0.27647296, -0.42549038, -0.41613156,
#        -0.4954707 , -0.4189896 , -0.47212398, -0.4396742 , -0.5234898 ,
#        -0.45905733, -0.5089673 , -0.55212873, -0.53866243, -0.6102091 ,
#        -0.66763437, -0.7497263 , -0.6254071 , -0.5877522 , -0.58527756,
#        -0.62680465], dtype=float32)

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=12))
X_test_date_axis = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in X_test_date_shaped]

plt.plot(X_test_date_axis, y_test, label = 'Open')
plt.plot(X_test_date_axis, y_pred, label = 'Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RSME: ", rmse)
print("MAPE: ", mape)
# Out:
# RSME:  0.18896949986713263
# MAPE:  0.135309753896373

# %%
lstm2 = Sequential()
lstm2.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm2.add(LSTM(50, activation='relu'))
lstm2.add(Dense(1))
lstm2.compile(loss='mean_squared_error', optimizer='adam')
lstm2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 2, 50)             10600
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = lstm2.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 152/152 - 3s - loss: 0.4008 - 3s/epoch - 21ms/step
# Epoch 2/100
# 152/152 - 1s - loss: 0.0096 - 616ms/epoch - 4ms/step
# Epoch 3/100
# 152/152 - 1s - loss: 0.0090 - 629ms/epoch - 4ms/step
# Epoch 4/100
# 152/152 - 1s - loss: 0.0079 - 610ms/epoch - 4ms/step
# Epoch 5/100
# 152/152 - 1s - loss: 0.0071 - 729ms/epoch - 5ms/step
# Epoch 6/100
# 152/152 - 1s - loss: 0.0064 - 934ms/epoch - 6ms/step
# Epoch 7/100
# 152/152 - 1s - loss: 0.0057 - 990ms/epoch - 7ms/step
# Epoch 8/100
# 152/152 - 1s - loss: 0.0053 - 1s/epoch - 7ms/step
# Epoch 9/100
# 152/152 - 1s - loss: 0.0050 - 1s/epoch - 7ms/step
# Epoch 10/100
# 152/152 - 1s - loss: 0.0048 - 1s/epoch - 7ms/step
# Epoch 11/100
# 152/152 - 1s - loss: 0.0046 - 970ms/epoch - 6ms/step
# Epoch 12/100
# 152/152 - 1s - loss: 0.0044 - 1s/epoch - 8ms/step
# Epoch 13/100
# 152/152 - 1s - loss: 0.0042 - 1s/epoch - 7ms/step
# Epoch 14/100
# 152/152 - 1s - loss: 0.0040 - 1s/epoch - 7ms/step
# Epoch 15/100
# 152/152 - 1s - loss: 0.0039 - 1s/epoch - 7ms/step
# Epoch 16/100
# 152/152 - 1s - loss: 0.0038 - 1s/epoch - 8ms/step
# Epoch 17/100
# 152/152 - 1s - loss: 0.0037 - 1s/epoch - 8ms/step
# Epoch 18/100
# 152/152 - 1s - loss: 0.0035 - 1s/epoch - 7ms/step
# Epoch 19/100
# 152/152 - 1s - loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 20/100
# 152/152 - 1s - loss: 0.0033 - 1s/epoch - 7ms/step
# Epoch 21/100
# 152/152 - 1s - loss: 0.0033 - 963ms/epoch - 6ms/step
# Epoch 22/100
# 152/152 - 1s - loss: 0.0032 - 1s/epoch - 7ms/step
# Epoch 23/100
# 152/152 - 1s - loss: 0.0031 - 1s/epoch - 7ms/step
# Epoch 24/100
# 152/152 - 1s - loss: 0.0031 - 964ms/epoch - 6ms/step
# Epoch 25/100
# 152/152 - 1s - loss: 0.0030 - 669ms/epoch - 4ms/step
# Epoch 26/100
# 152/152 - 1s - loss: 0.0029 - 581ms/epoch - 4ms/step
# Epoch 27/100
# 152/152 - 1s - loss: 0.0028 - 568ms/epoch - 4ms/step
# Epoch 28/100
# 152/152 - 1s - loss: 0.0029 - 611ms/epoch - 4ms/step
# Epoch 29/100
# 152/152 - 1s - loss: 0.0028 - 567ms/epoch - 4ms/step
# Epoch 30/100
# 152/152 - 1s - loss: 0.0027 - 589ms/epoch - 4ms/step
# Epoch 31/100
# 152/152 - 1s - loss: 0.0027 - 599ms/epoch - 4ms/step
# Epoch 32/100
# 152/152 - 1s - loss: 0.0027 - 591ms/epoch - 4ms/step
# Epoch 33/100
# 152/152 - 1s - loss: 0.0027 - 589ms/epoch - 4ms/step
# Epoch 34/100
# 152/152 - 1s - loss: 0.0026 - 578ms/epoch - 4ms/step
# Epoch 35/100
# 152/152 - 1s - loss: 0.0026 - 589ms/epoch - 4ms/step
# Epoch 36/100
# 152/152 - 1s - loss: 0.0026 - 567ms/epoch - 4ms/step
# Epoch 37/100
# 152/152 - 1s - loss: 0.0026 - 590ms/epoch - 4ms/step
# Epoch 38/100
# 152/152 - 1s - loss: 0.0026 - 559ms/epoch - 4ms/step
# Epoch 39/100
# 152/152 - 1s - loss: 0.0026 - 593ms/epoch - 4ms/step
# Epoch 40/100
# 152/152 - 1s - loss: 0.0026 - 589ms/epoch - 4ms/step
# Epoch 41/100
# 152/152 - 1s - loss: 0.0025 - 592ms/epoch - 4ms/step
# Epoch 42/100
# 152/152 - 1s - loss: 0.0025 - 593ms/epoch - 4ms/step
# Epoch 43/100
# 152/152 - 1s - loss: 0.0025 - 602ms/epoch - 4ms/step
# Epoch 44/100
# 152/152 - 1s - loss: 0.0025 - 590ms/epoch - 4ms/step
# Epoch 45/100
# 152/152 - 1s - loss: 0.0025 - 568ms/epoch - 4ms/step
# Epoch 46/100
# 152/152 - 1s - loss: 0.0025 - 618ms/epoch - 4ms/step
# Epoch 47/100
# 152/152 - 1s - loss: 0.0025 - 611ms/epoch - 4ms/step
# Epoch 48/100
# 152/152 - 1s - loss: 0.0025 - 600ms/epoch - 4ms/step
# Epoch 49/100
# 152/152 - 1s - loss: 0.0025 - 554ms/epoch - 4ms/step
# Epoch 50/100
# 152/152 - 1s - loss: 0.0025 - 558ms/epoch - 4ms/step
# Epoch 51/100
# 152/152 - 1s - loss: 0.0025 - 567ms/epoch - 4ms/step
# Epoch 52/100
# 152/152 - 1s - loss: 0.0025 - 564ms/epoch - 4ms/step
# Epoch 53/100
# 152/152 - 1s - loss: 0.0025 - 578ms/epoch - 4ms/step
# Epoch 54/100
# 152/152 - 1s - loss: 0.0025 - 580ms/epoch - 4ms/step
# Epoch 55/100
# 152/152 - 1s - loss: 0.0025 - 580ms/epoch - 4ms/step
# Epoch 56/100
# 152/152 - 1s - loss: 0.0025 - 587ms/epoch - 4ms/step
# Epoch 57/100
# 152/152 - 1s - loss: 0.0025 - 559ms/epoch - 4ms/step
# Epoch 58/100
# 152/152 - 1s - loss: 0.0025 - 565ms/epoch - 4ms/step
# Epoch 59/100
# 152/152 - 1s - loss: 0.0025 - 554ms/epoch - 4ms/step
# Epoch 60/100
# 152/152 - 1s - loss: 0.0025 - 562ms/epoch - 4ms/step
# Epoch 61/100
# 152/152 - 1s - loss: 0.0025 - 573ms/epoch - 4ms/step
# Epoch 62/100
# 152/152 - 1s - loss: 0.0025 - 573ms/epoch - 4ms/step
# Epoch 63/100
# 152/152 - 1s - loss: 0.0025 - 577ms/epoch - 4ms/step
# Epoch 64/100
# 152/152 - 1s - loss: 0.0025 - 594ms/epoch - 4ms/step
# Epoch 65/100
# 152/152 - 1s - loss: 0.0025 - 574ms/epoch - 4ms/step
# Epoch 66/100
# 152/152 - 1s - loss: 0.0025 - 580ms/epoch - 4ms/step
# Epoch 67/100
# 152/152 - 1s - loss: 0.0025 - 592ms/epoch - 4ms/step
# Epoch 68/100
# 152/152 - 1s - loss: 0.0025 - 584ms/epoch - 4ms/step
# Epoch 69/100
# 152/152 - 1s - loss: 0.0025 - 569ms/epoch - 4ms/step
# Epoch 70/100
# 152/152 - 1s - loss: 0.0025 - 572ms/epoch - 4ms/step
# Epoch 71/100
# 152/152 - 1s - loss: 0.0025 - 562ms/epoch - 4ms/step
# Epoch 72/100
# 152/152 - 1s - loss: 0.0025 - 589ms/epoch - 4ms/step
# Epoch 73/100
# 152/152 - 1s - loss: 0.0025 - 572ms/epoch - 4ms/step
# Epoch 74/100
# 152/152 - 1s - loss: 0.0025 - 588ms/epoch - 4ms/step
# Epoch 75/100
# 152/152 - 1s - loss: 0.0025 - 588ms/epoch - 4ms/step
# Epoch 76/100
# 152/152 - 1s - loss: 0.0025 - 586ms/epoch - 4ms/step
# Epoch 77/100
# 152/152 - 1s - loss: 0.0025 - 575ms/epoch - 4ms/step
# Epoch 78/100
# 152/152 - 1s - loss: 0.0025 - 580ms/epoch - 4ms/step
# Epoch 79/100
# 152/152 - 1s - loss: 0.0025 - 586ms/epoch - 4ms/step
# Epoch 80/100
# 152/152 - 1s - loss: 0.0025 - 589ms/epoch - 4ms/step
# Epoch 81/100
# 152/152 - 1s - loss: 0.0025 - 591ms/epoch - 4ms/step
# Epoch 82/100
# 152/152 - 1s - loss: 0.0025 - 647ms/epoch - 4ms/step
# Epoch 83/100
# 152/152 - 1s - loss: 0.0025 - 592ms/epoch - 4ms/step
# Epoch 84/100
# 152/152 - 1s - loss: 0.0025 - 575ms/epoch - 4ms/step
# Epoch 85/100
# 152/152 - 1s - loss: 0.0025 - 620ms/epoch - 4ms/step
# Epoch 86/100
# 152/152 - 1s - loss: 0.0025 - 597ms/epoch - 4ms/step
# Epoch 87/100
# 152/152 - 1s - loss: 0.0025 - 614ms/epoch - 4ms/step
# Epoch 88/100
# 152/152 - 1s - loss: 0.0025 - 564ms/epoch - 4ms/step
# Epoch 89/100
# 152/152 - 1s - loss: 0.0025 - 566ms/epoch - 4ms/step
# Epoch 90/100
# 152/152 - 1s - loss: 0.0025 - 568ms/epoch - 4ms/step
# Epoch 91/100
# 152/152 - 1s - loss: 0.0025 - 553ms/epoch - 4ms/step
# Epoch 92/100
# 152/152 - 1s - loss: 0.0025 - 534ms/epoch - 4ms/step
# Epoch 93/100
# 152/152 - 1s - loss: 0.0025 - 551ms/epoch - 4ms/step
# Epoch 94/100
# 152/152 - 1s - loss: 0.0025 - 557ms/epoch - 4ms/step
# Epoch 95/100
# 152/152 - 1s - loss: 0.0025 - 573ms/epoch - 4ms/step
# Epoch 96/100
# 152/152 - 1s - loss: 0.0025 - 572ms/epoch - 4ms/step
# Epoch 97/100
# 152/152 - 1s - loss: 0.0025 - 539ms/epoch - 4ms/step
# Epoch 98/100
# 152/152 - 1s - loss: 0.0025 - 556ms/epoch - 4ms/step
# Epoch 99/100
# 152/152 - 1s - loss: 0.0025 - 547ms/epoch - 4ms/step
# Epoch 100/100
# 152/152 - 1s - loss: 0.0025 - 590ms/epoch - 4ms/step

# %%
y_pred2 = lstm2.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 6ms/step

# %%
y_pred2
# Out:
# array([[ 0.63290477],
#        [ 0.59650224],
#        [ 0.6259441 ],
#        [ 0.5832715 ],
#        [ 0.59243727],
#        [ 0.6478788 ],
#        [ 0.6822782 ],
#        [ 0.6465931 ],
#        [ 0.63491625],
#        [ 0.61584824],
#        [ 0.5572595 ],
#        [ 0.6103608 ],
#        [ 0.62526333],
#        [ 0.6114394 ],
#        [ 0.66474247],
#        [ 0.78791845],
#        [ 0.8890902 ],
#        [ 0.92618597],
#        [ 0.9469962 ],
#        [ 0.9302573 ],
#        [ 0.9114313 ],
#        [ 0.99517846],
#        [ 1.0316714 ],
#        [ 1.0843449 ],
#        [ 1.204506  ],
#        [ 1.301711  ],
#        [ 1.2848319 ],
#        [ 1.4494532 ],
#        [ 1.4970939 ],
#        [ 1.480484  ],
#        [ 1.447825  ],
#        [ 1.3814044 ],
#        [ 1.2575938 ],
#        [ 1.2200018 ],
#        [ 1.2604029 ],
#        [ 1.2946135 ],
#        [ 1.297753  ],
#        [ 1.1992892 ],
#        [ 1.2828223 ],
#        [ 1.3456657 ],
#        [ 1.3271023 ],
#        [ 1.3158238 ],
#        [ 1.34774   ],
#        [ 1.4001551 ],
#        [ 1.534842  ],
#        [ 1.500884  ],
#        [ 1.6142796 ],
#        [ 1.6635342 ],
#        [ 1.7501388 ],
#        [ 1.8945262 ],
#        [ 1.8249632 ],
#        [ 1.79096   ],
#        [ 1.7845833 ],
#        [ 1.7464011 ],
#        [ 1.785049  ],
#        [ 1.8276817 ],
#        [ 1.7870451 ],
#        [ 1.8300254 ],
#        [ 1.740291  ],
#        [ 1.8676283 ],
#        [ 2.0594163 ],
#        [ 2.2072318 ],
#        [ 2.2609613 ],
#        [ 2.1911006 ],
#        [ 2.2569292 ],
#        [ 2.372516  ],
#        [ 2.4404519 ],
#        [ 2.3851573 ],
#        [ 2.36441   ],
#        [ 2.390118  ],
#        [ 2.0813186 ],
#        [ 1.976865  ],
#        [ 2.0466845 ],
#        [ 2.034113  ],
#        [ 2.0572274 ],
#        [ 2.2384627 ],
#        [ 2.3621743 ],
#        [ 2.368962  ],
#        [ 2.548176  ],
#        [ 2.447673  ],
#        [ 2.5005734 ],
#        [ 2.2529867 ],
#        [ 2.0715263 ],
#        [ 2.0630188 ],
#        [ 2.296077  ],
#        [ 2.1262076 ],
#        [ 2.2329416 ],
#        [ 1.9325564 ],
#        [ 1.5691657 ],
#        [ 1.6589656 ],
#        [ 1.5204221 ],
#        [ 1.6637971 ],
#        [ 1.7395695 ],
#        [ 1.7142986 ],
#        [ 1.575892  ],
#        [ 1.5336673 ],
#        [ 1.4040735 ],
#        [ 1.427265  ],
#        [ 1.4028344 ],
#        [ 1.3226234 ],
#        [ 1.3571903 ],
#        [ 1.4244523 ],
#        [ 1.4981079 ],
#        [ 1.5741104 ],
#        [ 1.5639045 ],
#        [ 1.5851657 ],
#        [ 1.5330722 ],
#        [ 1.5859035 ],
#        [ 1.5261194 ],
#        [ 1.4854335 ],
#        [ 1.4016541 ],
#        [ 1.3265536 ],
#        [ 0.9427084 ],
#        [ 0.91922116],
#        [ 0.8194361 ],
#        [ 0.8246527 ],
#        [ 0.8620099 ],
#        [ 0.8076052 ],
#        [ 0.7003324 ],
#        [ 0.6218514 ],
#        [ 0.62474567],
#        [ 0.6531974 ],
#        [-0.5603361 ],
#        [-0.6720904 ],
#        [-0.7101798 ],
#        [-0.74171096],
#        [-0.6540226 ],
#        [-0.67494434],
#        [-0.33236068],
#        [-0.02284347],
#        [-0.00646845],
#        [-0.24555923],
#        [-0.39596868],
#        [-0.38505316],
#        [-0.48374593],
#        [-0.39026082],
#        [-0.45423692],
#        [-0.41699082],
#        [-0.52920836],
#        [-0.4404117 ],
#        [-0.49664575],
#        [-0.5548264 ],
#        [-0.5433497 ],
#        [-0.62795717],
#        [-0.6982607 ],
#        [-0.80985725],
#        [-0.6419254 ],
#        [-0.60655755],
#        [-0.5979204 ],
#        [-0.64925206],
#        [-0.6826949 ]], dtype=float32)

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=12))
X_test_date_axis = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in X_test_date_shaped]

plt.plot(X_test_date_axis, y_test, label = 'Real prices')
plt.plot(X_test_date_axis, y_pred2, label = 'Predicted prices')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %%
rmse = mean_squared_error(y_test, y_pred2, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred2)
print("RSME: ", rmse)
print("MAPE: ", mape)
# Out:
# RSME:  0.10015309603225718
# MAPE:  0.06675570555777946
